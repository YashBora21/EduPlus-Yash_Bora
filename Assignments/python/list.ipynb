# %% [markdown]
# 1] Create a list of 10 numbers and print the list

# %%
num=[1,2,3,4,5,6,7,8,9,0]
print(num)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

# %% [markdown]
#  2] Create a list with different data types

# %%
list=[10,2.5,"prac",True]
for i in list:
    print(f"{i} = data type is : {type(i)}")
# Out:
# 10 = data type is : <class 'int'>
# 2.5 = data type is : <class 'float'>
# prac = data type is : <class 'str'>
# True = data type is : <class 'bool'>

# %% [markdown]
# 3] Print first, middle and last element

# %%
print(f"First ELe is: {num[0]}\nMiddle Ele is :{num[len(num)//2]}\nLast Ele is : {num[len(num)-1]}")
# Out:
# First ELe is: 1
# Middle Ele is :6
# Last Ele is : 0

# %% [markdown]
# 4] Slice first 3 and last 3 elements

# %%
print(f"First 3 ELe is :{num[:3]},last 3 is :{num[-3:]}")
# Out:
# First 3 ELe is :[1, 2, 3],last 3 is :[8, 9, 0]

# %% [markdown]
# 5] Replace second element

# %%
print("Original num:",num[1])
num[1]=20
print("After num:",num[1])
# Out:
# Original num: 2
# After num: 20

# %% [markdown]
# 6] Add new element using append()

# %%
num.append(11)
print("After append:",num)
# Out:
# After append: [1, 20, 3, 4, 5, 6, 7, 8, 9, 0, 11]

# %% [markdown]
# 7] Insert element at index 2

# %%
num.insert(2,2)
print(num)
# Out:
# [1, 20, 2, 3, 4, 5, 6, 7, 8, 9, 0, 11]

# %% [markdown]
#  8] Extend list with another list

# %%
num.extend([12,13,14])
print(num)
# Out:
# [1, 20, 2, 3, 4, 5, 6, 7, 8, 9, 0, 11, 12, 13, 14]

# %% [markdown]
# 9] Remove specific element

# %%
print("Before",num)
num.remove(20)
print("AFTER",num)
# Out:
# Before [1, 20, 2, 3, 4, 5, 6, 7, 8, 9, 0, 11, 12, 13, 14]
# AFTER [1, 2, 3, 4, 5, 6, 7, 8, 9, 0, 11, 12, 13, 14]

# %% [markdown]
# 10] Remove element at index 3 using pop()

# %%
removed = num.pop(3)
print("Removed:", removed)
# Out:
# Removed: 4

# %% [markdown]
# 11] Delete element at index 5

# %%
print("Before",num)
del num[5]
print("AFTER",num)
# Out:
# Before [1, 2, 3, 5, 6, 7, 8, 9, 0, 11, 12, 13, 14]
# AFTER [1, 2, 3, 5, 6, 8, 9, 0, 11, 12, 13, 14]

# %% [markdown]
# 12. Clear all elements

# %%
num.clear()
print( num)
# Out:
# []

# %% [markdown]
# 13] Check if "apple" exists

# %%
fruits = ["apple", "banana", "mango", "apple", "orange", "banana"]

# %%
print("is appler present:", 'apple'in fruits)
# Out:
# is appler present: True

# %% [markdown]
# 14] Find index of "mango"

# %%
print("Mango is present at:", fruits.index('mango'))
# Out:
# Mango is present at: 2

# %% [markdown]
# 15] Count occurrences of "apple"

# %%
print("apple appears:", fruits.count('apple'))
# Out:
# apple appears: 2

# %% [markdown]
# 16] Sort numbers list

# %%
num=[5,2,9,1,5,6]
print("Before sorting:", num)
num.sort()
print("After sorting:", num)
# Out:
# Before sorting: [5, 2, 9, 1, 5, 6]
# After sorting: [1, 2, 5, 5, 6, 9]

# %% [markdown]
# 17] Sort strings in descending order

# %%
fruits.sort(reverse=True)
print("Fruits in descending order:", fruits)
# Out:
# Fruits in descending order: ['orange', 'mango', 'banana', 'banana', 'apple', 'apple']

# %% [markdown]
# 18] Reverse a list

# %%
num.reverse()
print("Reversed num:", num)
# Out:
# Reversed num: [9, 6, 5, 5, 2, 1]

# %% [markdown]
# 19] Copy list

# %%
copy_nums = num.copy()
num.append(1000)
print("original:", num)
print("Copy:", copy_nums)
# Out:
# original: [9, 6, 5, 5, 2, 1, 1000]
# Copy: [9, 6, 5, 5, 2, 1]

# %% [markdown]
# 20] Combine two lists

# %%
concat= num + fruits
print("Concatenated list:", concat)
# Out:
# Concatenated list: [9, 6, 5, 5, 2, 1, 1000, 'orange', 'mango', 'banana', 'banana', 'apple', 'apple']
