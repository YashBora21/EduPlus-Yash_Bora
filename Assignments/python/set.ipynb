# %% [markdown]
# 1] Create  a set of containing five different country names

# %%
coutry={"India","Japan","America","Australia","UK"}

# %%
coutry={"India","UK","India","Japan","America","Australia","UK"}
print(coutry)
# Out:
# {'Australia', 'America', 'India', 'Japan', 'UK'}

# %%
fruits={"Mango","Apple","Banana","Orange","Grapes","Apple"}
fruit_set=set(fruits)
print(fruit_set)
# Out:
# {'Orange', 'Banana', 'Apple', 'Mango', 'Grapes'}

# %%
fruit_set.add("fig")
print(fruit_set)
# Out:
# {'Orange', 'Banana', 'Apple', 'fig', 'Mango', 'Grapes'}

# %%
fruit_set.update(["kiwi","pear"])
print(fruit_set)
# Out:
# {'Orange', 'Banana', 'Apple', 'pear', 'fig', 'kiwi', 'Mango', 'Grapes'}

# %%
fruit_set.add("kiwi")
print(fruit_set)
# Out:
# {'Orange', 'Banana', 'Apple', 'pear', 'fig', 'kiwi', 'Mango', 'Grapes'}

# %%
fruit_set.remove("Banana")
print(fruit_set)
# Out:
# {'Orange', 'fig', 'Grapes', 'kiwi', 'pear', 'Mango', 'Apple'}

# %%
fruit_set.discard("watermelon")
print(fruit_set)
# Out:
# {'fig', 'pear', 'Apple', 'Orange', 'kiwi', 'Grapes', 'Mango'}

# %%
ele=fruit_set.pop()
print("Popped element:", ele)
print(fruit_set)
# Out:
# Popped element: fig
# {'pear', 'Apple', 'Orange', 'kiwi', 'Grapes', 'Mango'}

# %%
fruit_set.clear()
print(fruit_set)
# Out:
# set()

# %%
num1={1,2,4}
num2={5,6,1,7}
print(num1.union(num2))
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
num1={1,2,4}
num2={5,6,1,7}
print(num1-(num2))
# Out:
# {2, 4}

# %%
num1={1,2,4}
num2={5,6,1,7}
print(num1&(num2))
# Out:
# {1}

# %%
num1={1,2,4}
num2={5,6,1,7}
print(num1^(num2))
# Out:
# {2, 4, 5, 6, 7}

# %%
num3={1,2}
print(num3.issubset(num1))
# Out:
# True

# %%
nums4={8,9}
print(nums4.isdisjoint(num1))
# Out:
# True

# %%
print(1 in num1)
# Out:
# True

# %%
print(1 not in num1)
# Out:
# False

# %%
print(max(num1))
# Out:
# 4

# %%
print(min(num1))
# Out:
# 1

# %%
print(len(num1))
# Out:
# 3

# %%
print(sum(num1))
# Out:
# 7

# %%
print(sorted(num1))
# Out:
# [1, 2, 4]

# %%
print(sorted(num1,reverse=True))
# Out:
# [4, 2, 1]

# %%
num1={1,0,1,0}
print(any(num1))
# Out:
# True

# %%
num2={1,1}

# %%
print(all(num2))
# Out:
# True

# %%
set1 = num1.copy()
print("this is the set1",set1)
print("this is num1", num1)
# Out:
# this is the set1 {0, 1}
# this is num1 {0, 1}

# %%
del set1
print(set1)  # This will raise an error since set1 is deleted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 del set1
# ----> 2 print(set1)  # This will raise an error since set1 is deleted
#
# NameError: name 'set1' is not defined

# %%
lsit=[1,2,1,2,1,3,1]
set1=set(lsit)
print("list",lsit)
print("set",set1)
# Out:
# list [1, 2, 1, 2, 1, 3, 1]
# set {1, 2, 3}

# %%
classA={"yash","ajay","asha"}

classB={"yash","raj"}

# %%
print(classA & classB)
# Out:
# {'yash'}

# %%
print(classA -classB)
# Out:
# {'ajay', 'asha'}

# %%
print(classA ^classB)
# Out:
# {'ajay', 'raj', 'asha'}
